# %%
#Frist, we need to install (PIL) the library (pip install Pillow)
#Second, we need to install (matplotlib) pip install matplotlib (pip install matplotlib)

from PIL import Image
from PIL import ImageOps # To make image proccing 

image=Image.open("Lenna.png") # To load the image

image.show(title="Image") # To Show the image

import matplotlib.pyplot as plt #To plot the image

plt.imshow(image) 

print(image) #There are 3 attributes (Format)[PNG] (Size)[512x512] (Mode - Color Space)[RGB]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FEAA9CA51F0>

# %%
from PIL import Image
from PIL import ImageOps # To make image proccing 

image=Image.open("Lenna.png") # To load the image

image_gray=ImageOps.grayscale(image)

image_gray.show()

print(image_gray) #Image mode Luminance 

image_gray.save("Lenna.jpg") #To save the gray image and change the format
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEAAA19CC70>

# %%
from PIL import Image 
from PIL import ImageOps # To make image proccing 

image=Image.open("barbara.jpg")
image_gray=ImageOps.grayscale(image)
#image_gray.show()
image_gray.quantize(2) #To set image colors to just 2 colors (Quanties)
# Out:
# <PIL.Image.Image image mode=P size=720x576>

# %%
# We can work with the diffrent color channels (RGB) - split the 3 three channels 

from PIL import Image
from PIL import ImageOps

image=Image.open("baboon.png")

red, green, blue=image.split() # this code is to split the image to the original 3 channels (RGB) 

red.show(title="Red Channel") #Plot the red channel as greay scale (Red has higher inensity)
green.show(title="Green Channel") #Plot the green channel as greay scale
blue.show(title=("Blue Channel")) #Plot the blue channel as greay scale

# %%
# We can convert the PIL image to a numpy array 

from PIL import Image
from PIL import ImageOps

import numpy as np  #import the array 

image=Image.open("Lenna.png")

import numpy as np  #import the array 

array=np.array(image)

print(array) # To print the image array
# Out:
# [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]

# %%
# To use OpenCV

import cv2

image=cv2.imread("Lenna.png") # To read the image using OpenCV 

image2=cv2.imread("Lenna.jpg", cv2.IMREAD_GRAYSCALE) # to open the gray scal image, we need to spacify the image type

#type(image)#:numpy.ndarray

image.shape:(512,512,3)

new_image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

import matplotlib.pyplot as plt # we need to use matplot because the image is an array not like pillow

# plt.imshow(new_image)

image_graycv=cv2.cvtColor(new_image, cv2.COLOR_BGR2GRAY)

#plt.imshow(image_graycv)

blue, green, red = image[:,:,0],image[:,:,1],image[:,:,2] # Slicing each channel (0,1,2) and select all the raws and columan by [:,:,(the color channel)]

plt.imshow(blue)

cv2.imwrite("Lenna1cv.png", blue) #To save an image
# Out:
# True

# %%
from PIL import Image

image=Image.open("lenna.png")
image
image.show()

# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt 

image=Image.open("baboon.png")
array=np.array(image)
print(type(array))
print(array.shape)


array[:,:,0]=0
array[:,:,1]=0

print(array.shape)


plt.imshow(array)
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 3)
# (512, 512, 3)

# %%
import cv2 
import matplotlib.pyplot as plt 

image=cv2.imread("baboon.png")

print(type(image))

plt.imshow(image)
# Out:
# <class 'numpy.ndarray'>

# %%
new_rgb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(new_rgb)

# %%
#blue, green, red = image[:,:,0], image[:,:,1], image[:,:,2]

im_bgr = cv2.vconcat([blue, green, red])

# %%
plt.imshow(im_bgr)

# %%
from PIL import Image
from PIL import ImageOps

image=Image.open('lenna.png')

image_flip=ImageOps.flip(image)
image_mirror=ImageOps.mirror(image)

image_flip
image_mirror
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import cv2

my_image="Lenna.png"

image=cv2.imread(my_image)

imagez=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

imageflip=cv2.flip(imagez, 0) # (zero)Flip around (y) axis 
imageflip=cv2.flip(imagez, 1) # (zero)Flip around (x) axis 


import matplotlib.pyplot as plt

plt.imshow(imageflip)
